# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Exploratory Data Analysis**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis or EDA.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Examine the structure of a dataset.
#
# - Handle missing values effectively.
#
# - Conduct summary statistics on key columns.
#
# - Analyze employment status, job satisfaction, programming language usage, and trends in remote work.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# #### Step 1: Install and Import Libraries

# %% [markdown]
# Install the necessary libraries for data manipulation and visualization.

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 106.7 MB/s eta 0:00:00
# Downloading numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 167.0 MB/s eta 0:00:00
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.4.3 pandas-3.0.1
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 170.2 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 144.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 93.3 MB/s eta 0:00:00
# Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 179.8 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %% [markdown]
# #### Step 2: Load and Preview the Dataset
# Load the dataset from the provided URL. Use df.head() to display the first few rows to get an overview of the structure.

# %%
# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# Display the first few rows of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  \
# 0                                                NaN
# 1  Technical documentation;Blogs;Books;Written Tu...
# 2  Technical documentation;Blogs;Books;Written Tu...
# 3  Stack Overflow;How-to videos;Interactive tutorial
# 4  Technical documentation;Blogs;Written Tutorial...
#
#                                              TechDoc YearsCode YearsCodePro  \
# 0                                                NaN       NaN          NaN
# 1  API document(s) and/or SDK document(s);User gu...        20           17
# 2  API document(s) and/or SDK document(s);User gu...        37           27
# 3                                                NaN         4          NaN
# 4  API document(s) and/or SDK document(s);User gu...         9          NaN
#
#                  DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy  \
# 0                    NaN     NaN               NaN        NaN        NaN
# 1  Developer, full-stack     NaN               NaN        NaN        NaN
# 2   Developer Experience     NaN               NaN        NaN        NaN
# 3  Developer, full-stack     NaN               NaN        NaN        NaN
# 4  Developer, full-stack     NaN               NaN        NaN        NaN
#
#   TechEndorse                                            Country Currency  \
# 0         NaN                           United States of America      NaN
# 1         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 2         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 3         NaN                                             Canada      NaN
# 4         NaN                                             Norway      NaN
#
#    CompTotal                             LanguageHaveWorkedWith  \
# 0        NaN                                                NaN
# 1        NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2        NaN                                                 C#
# 3        NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4        NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                               LanguageWantToWorkWith  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#                                      LanguageAdmired  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#             DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# 0                              NaN                         NaN
# 1      Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 2       Firebase Realtime Database  Firebase Realtime Database
# 3  MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 4                PostgreSQL;SQLite           PostgreSQL;SQLite
#
#               DatabaseAdmired                    PlatformHaveWorkedWith  \
# 0                         NaN                                       NaN
# 1                  PostgreSQL  Amazon Web Services (AWS);Heroku;Netlify
# 2  Firebase Realtime Database                              Google Cloud
# 3    MongoDB;MySQL;PostgreSQL   Amazon Web Services (AWS);Fly.io;Heroku
# 4           PostgreSQL;SQLite                                       NaN
#
#                      PlatformWantToWorkWith  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3          Amazon Web Services (AWS);Vercel
# 4                                       NaN
#
#                             PlatformAdmired  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3                 Amazon Web Services (AWS)
# 4                                       NaN
#
#                    WebframeHaveWorkedWith            WebframeWantToWorkWith  \
# 0                                     NaN                               NaN
# 1           Express;Next.js;Node.js;React  Express;Htmx;Node.js;React;Remix
# 2                            ASP.NET CORE                      ASP.NET CORE
# 3  jQuery;Next.js;Node.js;React;WordPress      jQuery;Next.js;Node.js;React
# 4                                     NaN                               NaN
#
#                 WebframeAdmired   EmbeddedHaveWorkedWith  \
# 0                           NaN                      NaN
# 1         Express;Node.js;React                      NaN
# 2                  ASP.NET CORE              Rasberry Pi
# 3  jQuery;Next.js;Node.js;React              Rasberry Pi
# 4                           NaN  CMake;Cargo;Rasberry Pi
#
#   EmbeddedWantToWorkWith    EmbeddedAdmired  \
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2            Rasberry Pi        Rasberry Pi
# 3                    NaN                NaN
# 4      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                             MiscTechHaveWorkedWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                     NumPy;Pandas;Ruff;TensorFlow
# 4                                              NaN
#
#                             MiscTechWantToWorkWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                                    MiscTechAdmired  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                        ToolsTechHaveWorkedWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                               Docker;npm;Pip
# 4                                 APT;Make;npm
#
#                        ToolsTechWantToWorkWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                        Docker;Kubernetes;npm
# 4                                     APT;Make
#
#                               ToolsTechAdmired  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                                   Docker;npm
# 4                                     APT;Make
#
#           NEWCollabToolsHaveWorkedWith         NEWCollabToolsWantToWorkWith  \
# 0                                  NaN                                  NaN
# 1  PyCharm;Visual Studio Code;WebStorm  PyCharm;Visual Studio Code;WebStorm
# 2                        Visual Studio                        Visual Studio
# 3                                  NaN                                  NaN
# 4                                  Vim                                  Vim
#
#                  NEWCollabToolsAdmired        OpSysPersonal use  \
# 0                                  NaN                      NaN
# 1  PyCharm;Visual Studio Code;WebStorm            MacOS;Windows
# 2                        Visual Studio                  Windows
# 3                                  NaN                      NaN
# 4                                  Vim  Other (please specify):
#
#   OpSysProfessional use                     OfficeStackAsyncHaveWorkedWith  \
# 0                   NaN                                                NaN
# 1                 MacOS                                                NaN
# 2               Windows                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN  GitHub Discussions;Markdown File;Obsidian;Stac...
#
#               OfficeStackAsyncWantToWorkWith  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                      OfficeStackAsyncAdmired  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                   OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 0                                           NaN                           NaN
# 1                         Microsoft Teams;Slack                         Slack
# 2  Google Chat;Google Meet;Microsoft Teams;Zoom  Google Chat;Google Meet;Zoom
# 3                                           NaN                           NaN
# 4                              Discord;Whatsapp              Discord;Whatsapp
#
#          OfficeStackSyncAdmired AISearchDevHaveWorkedWith  \
# 0                           NaN                       NaN
# 1                         Slack                       NaN
# 2  Google Chat;Google Meet;Zoom                       NaN
# 3                           NaN                       NaN
# 4              Discord;Whatsapp                       NaN
#
#   AISearchDevWantToWorkWith AISearchDevAdmired  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
#
#                                           NEWSOSites             SOVisitFreq  \
# 0  I have never visited Stack Overflow or the Sta...                     NaN
# 1  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
# 2  Stack Overflow;Stack Exchange;Stack Overflow B...  Multiple times per day
# 3                                     Stack Overflow   Daily or almost daily
# 4  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
#
#   SOAccount              SOPartFreq  \
# 0       NaN                     NaN
# 1       Yes  Multiple times per day
# 2       Yes  Multiple times per day
# 3        No                     NaN
# 4       Yes  Multiple times per day
#
#                                                SOHow           SOComm  \
# 0                                                NaN              NaN
# 1  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 2  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 3                     Quickly finding code solutions   No, not really
# 4  Quickly finding code solutions;Engage with com...  Yes, definitely
#
#                   AISelect          AISent  \
# 0                      Yes  Very favorable
# 1  No, and I don't plan to             NaN
# 2  No, and I don't plan to             NaN
# 3                      Yes  Very favorable
# 4  No, and I don't plan to             NaN
#
#                                                AIBen           AIAcc  \
# 0                              Increase productivity             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Increase productivity;Greater efficiency;Impro...  Somewhat trust
# 4                                                NaN             NaN
#
#                        AIComplex  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3  Bad at handling complex tasks
# 4                            NaN
#
#                                AIToolCurrently Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Learning about a codebase;Project planning;Wri...
# 4                                                NaN
#
#                            AIToolInterested in Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Testing code;Committing and reviewing code;Pre...
# 4                                                NaN
#
#   AIToolNot interested in Using  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                           AINextMuch more integrated AINextNo change  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Learning about a codebase;Project planning;Wri...             NaN
# 4                                                NaN             NaN
#
#   AINextMore integrated AINextLess integrated AINextMuch less integrated  \
# 0                   NaN                   NaN                        NaN
# 1                   NaN                   NaN                        NaN
# 2                   NaN                   NaN                        NaN
# 3                   NaN                   NaN                        NaN
# 4                   NaN                   NaN                        NaN
#
#   AIThreat                                           AIEthics  \
# 0      NaN                                                NaN
# 1      NaN                                                NaN
# 2      NaN                                                NaN
# 3       No  Circulating misinformation or disinformation;M...
# 4      NaN                                                NaN
#
#                         AIChallenges TBranch                  ICorPM  WorkExp  \
# 0                                NaN      No                     NaN      NaN
# 1                                NaN     Yes  Individual contributor     17.0
# 2                                NaN      No                     NaN      NaN
# 3  Don’t trust the output or answers     NaN                     NaN      NaN
# 4                                NaN     NaN                     NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5  \
# 0         NaN         NaN         NaN         NaN         NaN
# 1       Agree    Disagree       Agree       Agree       Agree
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
#                   Knowledge_6 Knowledge_7 Knowledge_8 Knowledge_9 Frequency_1  \
# 0                         NaN         NaN         NaN         NaN         NaN
# 1  Neither agree nor disagree    Disagree       Agree       Agree         NaN
# 2                         NaN         NaN         NaN         NaN         NaN
# 3                         NaN         NaN         NaN         NaN         NaN
# 4                         NaN         NaN         NaN         NaN         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering Frustration  \
# 0         NaN         NaN           NaN           NaN         NaN
# 1         NaN         NaN           NaN           NaN         NaN
# 2         NaN         NaN           NaN           NaN         NaN
# 3         NaN         NaN           NaN           NaN         NaN
# 4         NaN         NaN           NaN           NaN         NaN
#
#   ProfessionalTech ProfessionalCloud ProfessionalQuestion Industry  \
# 0              NaN               NaN                  NaN      NaN
# 1              NaN               NaN                  NaN      NaN
# 2              NaN               NaN                  NaN      NaN
# 3              NaN               NaN                  NaN      NaN
# 4              NaN               NaN                  NaN      NaN
#
#    JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# 0             NaN             NaN             NaN             NaN
# 1             0.0             0.0             0.0             0.0
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# 0             NaN             NaN             NaN              NaN
# 1             0.0             0.0             0.0              0.0
# 2             NaN             NaN             NaN              NaN
# 3             NaN             NaN             NaN              NaN
# 4             NaN             NaN             NaN              NaN
#
#    JobSatPoints_11           SurveyLength SurveyEase  ConvertedCompYearly  \
# 0              NaN                    NaN        NaN                  NaN
# 1              0.0                    NaN        NaN                  NaN
# 2              NaN  Appropriate in length       Easy                  NaN
# 3              NaN               Too long       Easy                  NaN
# 4              NaN              Too short       Easy                  NaN
#
#    JobSat
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# #### Step 3: Handling Missing Data

# %% [markdown]
# Identify and manage missing values in critical columns such as `Employment`, `JobSat`, and `RemoteWork`. Implement a strategy to fill or drop these values, depending on the significance of the missing data.

# %%
# Check missing values
df[['Employment', 'JobSat', 'RemoteWork']].isnull().sum()

# Option 1: Drop rows with missing values in these columns
df = df.dropna(subset=['Employment', 'JobSat', 'RemoteWork'])

# OR Option 2: Fill missing values (example)
df['Employment'] = df['Employment'].fillna('Unknown')
df['RemoteWork'] = df['RemoteWork'].fillna('Unknown')

# For JobSat (numeric or ordinal), fill with median
df['JobSat'] = df['JobSat'].fillna(df['JobSat'].median())

# %% [markdown]
# #### Step 4: Analysis of Experience and Job Satisfaction

# %% [markdown]
# Analyze the relationship between years of professional coding experience (`YearsCodePro`) and job satisfaction (`JobSat`). Summarize `YearsCodePro` and calculate median satisfaction scores based on experience ranges.
#
# - Create experience ranges for `YearsCodePro` (e.g., `0-5`, `5-10`, `10-20`, `>20` years).
#
# - Calculate the median `JobSat` for each range.
#
# - Visualize the relationship using a bar plot or similar visualization.

# %%
df['YearsCodePro'] = df['YearsCodePro'].replace({
    'Less than 1 year': 0,
    'More than 50 years': 50
})

# %%
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')

# %%
df = df.dropna(subset=['YearsCodePro'])

# %%
bins = [0, 5, 10, 20, 50]
labels = ['0-5', '5-10', '10-20', '20+']

df['ExperienceRange'] = pd.cut(df['YearsCodePro'], bins=bins, labels=labels)

# %%
median_jobsat = df.groupby('ExperienceRange')['JobSat'].median()
print(median_jobsat)
# Out:
# ExperienceRange
# 0-5      7.0
# 5-10     7.0
# 10-20    8.0
# 20+      8.0
# Name: JobSat, dtype: float64

# %%
import matplotlib.pyplot as plt

median_jobsat.plot(kind='bar')

plt.title('Median Job Satisfaction by Experience')
plt.xlabel('Experience Range')
plt.ylabel('Median Job Satisfaction')

plt.show()

# %% [markdown]
# #### Step 5: Visualize Job Satisfaction

# %% [markdown]
# Use a count plot to show the distribution of `JobSat` values. This provides insights into the overall satisfaction levels of respondents.

# %%
import seaborn as sns

sns.countplot(x='JobSat', data=df)

plt.title('Distribution of Job Satisfaction')
plt.show()

# %% [markdown]
# #### Step 6: Analyzing Remote Work Preferences by Job Role

# %% [markdown]
# Analyze trends in remote work based on job roles. Use the `RemoteWork` and `Employment` columns to explore preferences and examine if specific job roles prefer remote work more than others.
#
# - Use a count plot to show remote work distribution.
#
# - Cross-tabulate remote work preferences by employment type (e.g., full-time, part-time) and job roles.

# %%
remote_analysis = df.groupby(['Employment', 'RemoteWork']).size().unstack()

print(remote_analysis)
# Out:
# RemoteWork                                          Hybrid (some remote, some in-person)  \
# Employment
# Employed, full-time                                                               9752.0
# Employed, full-time;Employed, part-time                                             48.0
# Employed, full-time;Independent contractor, fre...                                 800.0
# Employed, full-time;Independent contractor, fre...                                  52.0
# Employed, full-time;Independent contractor, fre...                                   NaN
# Employed, full-time;Independent contractor, fre...                                  42.0
# Employed, full-time;Independent contractor, fre...                                   3.0
# Employed, full-time;Not employed, and not looki...                                   NaN
# Employed, full-time;Not employed, but looking f...                                   9.0
# Employed, full-time;Not employed, but looking f...                                   NaN
# Employed, full-time;Not employed, but looking f...                                   4.0
# Employed, full-time;Not employed, but looking f...                                   1.0
# Employed, full-time;Not employed, but looking f...                                   NaN
# Employed, full-time;Not employed, but looking f...                                   NaN
# Employed, full-time;Retired                                                          2.0
# Employed, full-time;Student, full-time                                             169.0
# Employed, full-time;Student, full-time;Employed...                                   5.0
# Employed, full-time;Student, full-time;Independ...                                  26.0
# Employed, full-time;Student, full-time;Independ...                                   3.0
# Employed, full-time;Student, full-time;Independ...                                   NaN
# Employed, full-time;Student, full-time;Not empl...                                   NaN
# Employed, full-time;Student, full-time;Not empl...                                   1.0
# Employed, full-time;Student, full-time;Not empl...                                   1.0
# Employed, full-time;Student, full-time;Not empl...                                   3.0
# Employed, full-time;Student, full-time;Not empl...                                   NaN
# Employed, full-time;Student, full-time;Not empl...                                   1.0
# Employed, full-time;Student, full-time;Student,...                                   1.0
# Employed, full-time;Student, full-time;Student,...                                   3.0
# Employed, full-time;Student, part-time                                             199.0
# Employed, full-time;Student, part-time;Employed...                                   2.0
# Employed, part-time                                                                269.0
# Employed, part-time;Retired                                                          2.0
# Independent contractor, freelancer, or self-emp...                                 367.0
# Independent contractor, freelancer, or self-emp...                                  93.0
# Independent contractor, freelancer, or self-emp...                                   1.0
# Independent contractor, freelancer, or self-emp...                                   NaN
# Independent contractor, freelancer, or self-emp...                                   NaN
# Independent contractor, freelancer, or self-emp...                                   NaN
# Independent contractor, freelancer, or self-emp...                                   3.0
# Independent contractor, freelancer, or self-emp...                                   4.0
# Independent contractor, freelancer, or self-emp...                                  18.0
# Not employed, and not looking for work;Employed...                                   NaN
# Not employed, but looking for work;Employed, pa...                                   1.0
# Not employed, but looking for work;Independent ...                                   7.0
# Not employed, but looking for work;Independent ...                                   2.0
# Not employed, but looking for work;Independent ...                                   NaN
# Not employed, but looking for work;Independent ...                                   NaN
# Not employed, but looking for work;Independent ...                                   NaN
# Not employed, but looking for work;Independent ...                                   2.0
# Not employed, but looking for work;Independent ...                                   NaN
# Not employed, but looking for work;Student, par...                                   NaN
# Student, full-time;Employed, part-time                                             223.0
# Student, full-time;Independent contractor, free...                                  21.0
# Student, full-time;Independent contractor, free...                                  26.0
# Student, full-time;Independent contractor, free...                                   NaN
# Student, full-time;Independent contractor, free...                                   1.0
# Student, full-time;Not employed, but looking fo...                                   1.0
# Student, full-time;Not employed, but looking fo...                                   3.0
# Student, full-time;Student, part-time;Employed,...                                   NaN
# Student, part-time;Employed, part-time                                             135.0
#
# RemoteWork                                          In-person  Remote
# Employment
# Employed, full-time                                    4279.0  7869.0
# Employed, full-time;Employed, part-time                  15.0    59.0
# Employed, full-time;Independent contractor, fre...      226.0  1205.0
# Employed, full-time;Independent contractor, fre...        8.0    54.0
# Employed, full-time;Independent contractor, fre...        2.0     NaN
# Employed, full-time;Independent contractor, fre...       11.0    35.0
# Employed, full-time;Independent contractor, fre...        2.0     2.0
# Employed, full-time;Not employed, and not looki...        1.0     NaN
# Employed, full-time;Not employed, but looking f...        8.0    13.0
# Employed, full-time;Not employed, but looking f...        NaN     2.0
# Employed, full-time;Not employed, but looking f...        NaN     3.0
# Employed, full-time;Not employed, but looking f...        NaN     2.0
# Employed, full-time;Not employed, but looking f...        NaN     1.0
# Employed, full-time;Not employed, but looking f...        NaN     1.0
# Employed, full-time;Retired                               1.0     1.0
# Employed, full-time;Student, full-time                  102.0   111.0
# Employed, full-time;Student, full-time;Employed...        2.0     5.0
# Employed, full-time;Student, full-time;Independ...        4.0    21.0
# Employed, full-time;Student, full-time;Independ...        1.0     1.0
# Employed, full-time;Student, full-time;Independ...        NaN     1.0
# Employed, full-time;Student, full-time;Not empl...        NaN     1.0
# Employed, full-time;Student, full-time;Not empl...        NaN     NaN
# Employed, full-time;Student, full-time;Not empl...        NaN     NaN
# Employed, full-time;Student, full-time;Not empl...        1.0     NaN
# Employed, full-time;Student, full-time;Not empl...        1.0     1.0
# Employed, full-time;Student, full-time;Not empl...        NaN     NaN
# Employed, full-time;Student, full-time;Student,...        NaN     NaN
# Employed, full-time;Student, full-time;Student,...        NaN     NaN
# Employed, full-time;Student, part-time                  126.0   163.0
# Employed, full-time;Student, part-time;Employed...        NaN     3.0
# Employed, part-time                                      98.0   163.0
# Employed, part-time;Retired                               NaN     NaN
# Independent contractor, freelancer, or self-emp...       51.0   823.0
# Independent contractor, freelancer, or self-emp...       15.0    89.0
# Independent contractor, freelancer, or self-emp...        NaN     1.0
# Independent contractor, freelancer, or self-emp...        NaN     2.0
# Independent contractor, freelancer, or self-emp...        NaN     1.0
# Independent contractor, freelancer, or self-emp...        NaN     2.0
# Independent contractor, freelancer, or self-emp...        NaN     1.0
# Independent contractor, freelancer, or self-emp...        NaN    15.0
# Independent contractor, freelancer, or self-emp...        3.0     8.0
# Not employed, and not looking for work;Employed...        NaN     1.0
# Not employed, but looking for work;Employed, pa...        1.0     3.0
# Not employed, but looking for work;Independent ...        2.0    33.0
# Not employed, but looking for work;Independent ...        1.0     6.0
# Not employed, but looking for work;Independent ...        NaN     1.0
# Not employed, but looking for work;Independent ...        NaN     1.0
# Not employed, but looking for work;Independent ...        NaN     1.0
# Not employed, but looking for work;Independent ...        NaN     4.0
# Not employed, but looking for work;Independent ...        NaN     1.0
# Not employed, but looking for work;Student, par...        2.0     NaN
# Student, full-time;Employed, part-time                   93.0    91.0
# Student, full-time;Independent contractor, free...        9.0    23.0
# Student, full-time;Independent contractor, free...        4.0    22.0
# Student, full-time;Independent contractor, free...        NaN     1.0
# Student, full-time;Independent contractor, free...        NaN     2.0
# Student, full-time;Not employed, but looking fo...        NaN     NaN
# Student, full-time;Not employed, but looking fo...        NaN     4.0
# Student, full-time;Student, part-time;Employed,...        NaN     1.0
# Student, part-time;Employed, part-time                   76.0    42.0

# %%
remote_analysis.plot(kind='bar', stacked=True)

plt.title('Remote Work Preferences by Job Role')
plt.show()

# %% [markdown]
# #### Step 7: Analyzing Programming Language Trends by Region

# %% [markdown]
# Analyze the popularity of programming languages by region. Use the `LanguageHaveWorkedWith` column to investigate which languages are most used in different regions.
#
# - Filter data by country or region.
#
# - Visualize the top programming languages by region with a bar plot or heatmap.

# %%
# Filter by a specific region (example: Canada)
region_df = df[df['Country'] == 'Canada']

# Split multiple languages into rows
languages = region_df['LanguageHaveWorkedWith'].str.split(';').explode()

# Count frequency
top_languages = languages.value_counts().head(10)

print(top_languages)
# Out:
# LanguageHaveWorkedWith
# JavaScript                 619
# SQL                        560
# HTML/CSS                   518
# Python                     510
# TypeScript                 416
# Bash/Shell (all shells)    393
# C#                         325
# Java                       253
# C++                        203
# PowerShell                 180
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

top_languages.plot(kind='bar')

plt.title('Top Programming Languages in Canada')
plt.xlabel('Language')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# #### Step 8: Correlation Between Experience and Satisfaction

# %% [markdown]
# Examine how years of experience (`YearsCodePro`) correlate with job satisfaction (`JobSatPoints_1`). Use a scatter plot to visualize this relationship.

# %%
## Write your code here# Ensure numeric
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
df['JobSatPoints_1'] = pd.to_numeric(df['JobSatPoints_1'], errors='coerce')

# Drop missing
corr_df = df.dropna(subset=['YearsCodePro', 'JobSatPoints_1'])

# Scatter plot
import matplotlib.pyplot as plt

plt.scatter(corr_df['YearsCodePro'], corr_df['JobSatPoints_1'])

plt.xlabel('Years of Experience')
plt.ylabel('Job Satisfaction')
plt.title('Experience vs Job Satisfaction')

plt.show()

# %%
corr = corr_df['YearsCodePro'].corr(corr_df['JobSatPoints_1'])
print("Correlation:", corr)
# Out:
# Correlation: -0.0315323724541973

# %% [markdown]
# #### Step 9: Educational Background and Employment Type

# %% [markdown]
# Explore how educational background (`EdLevel`) relates to employment type (`Employment`). Use cross-tabulation and visualizations to understand if higher education correlates with specific employment types.

# %%
cross_tab = pd.crosstab(df['EdLevel'], df['Employment'])

print(cross_tab)
# Out:
# Employment                                          Employed, full-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                 655
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                      10280
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                    6494
# Primary/elementary school                                            87
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                     1110
# Secondary school (e.g. American high school, Ge...                  854
# Some college/university study without earning a...                 2216
# Something else                                                      204
#
# Employment                                          Employed, full-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                       6
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                             57
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                          34
# Primary/elementary school                                                                 0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                            4
# Secondary school (e.g. American high school, Ge...                                        6
# Some college/university study without earning a...                                       14
# Something else                                                                            1
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                72
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      940
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   617
# Primary/elementary school                                                                          13
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                     95
# Secondary school (e.g. American high school, Ge...                                                125
# Some college/university study without earning a...                                                339
# Something else                                                                                     30
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 7
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                       54
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                    30
# Primary/elementary school                                                                           1
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      7
# Secondary school (e.g. American high school, Ge...                                                  3
# Some college/university study without earning a...                                                 11
# Something else                                                                                      1
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     1
# Primary/elementary school                                                                           1
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 5
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                       34
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                    23
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  3
# Some college/university study without earning a...                                                 22
# Something else                                                                                      1
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        3
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     2
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  2
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Not employed, and not looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Not employed, but looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                       18
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                    10
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  2
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Not employed, but looking for work;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  1
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        2
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     1
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      1
# Secondary school (e.g. American high school, Ge...                                                  1
# Some college/university study without earning a...                                                  2
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     2
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      1
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Not employed, but looking for work;Not employed, and not looking for work;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     1
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Retired  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                           0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                  2
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                               1
# Primary/elementary school                                                     0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                0
# Secondary school (e.g. American high school, Ge...                            0
# Some college/university study without earning a...                            1
# Something else                                                                0
#
# Employment                                          Employed, full-time;Student, full-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                     17
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           150
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                         82
# Primary/elementary school                                                                4
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                          10
# Secondary school (e.g. American high school, Ge...                                      52
# Some college/university study without earning a...                                      65
# Something else                                                                           2
#
# Employment                                          Employed, full-time;Student, full-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 1
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        3
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     3
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  2
# Some college/university study without earning a...                                                  3
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                       22
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                    12
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      2
# Secondary school (e.g. American high school, Ge...                                                  9
# Some college/university study without earning a...                                                  6
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     1
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  3
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time;Retired  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      1
#
# Employment                                          Employed, full-time;Student, full-time;Not employed, but looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  1
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Student, part-time;Employed, part-time;Retired  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 1
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  2
# Something else                                                                                      1
#
# Employment                                          Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           1
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Student, full-time;Not employed, but looking for work;Student, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      1
#
# Employment                                          Employed, full-time;Student, full-time;Student, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Student, full-time;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  1
# Some college/university study without earning a...                                                  1
# Something else                                                                                      0
#
# Employment                                          Employed, full-time;Student, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                     28
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           220
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                         83
# Primary/elementary school                                                                2
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                          15
# Secondary school (e.g. American high school, Ge...                                      30
# Some college/university study without earning a...                                     103
# Something else                                                                           7
#
# Employment                                          Employed, full-time;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        2
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     1
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  2
# Something else                                                                                      0
#
# Employment                                          Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                  13
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                        187
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                     169
# Primary/elementary school                                             6
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                       35
# Secondary school (e.g. American high school, Ge...                   53
# Some college/university study without earning a...                   61
# Something else                                                        6
#
# Employment                                          Employed, part-time;Retired  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                           0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                  0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                               0
# Primary/elementary school                                                     0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                1
# Secondary school (e.g. American high school, Ge...                            0
# Some college/university study without earning a...                            1
# Something else                                                                0
#
# Employment                                          Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                34
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      463
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   414
# Primary/elementary school                                                                           4
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                     50
# Secondary school (e.g. American high school, Ge...                                                 88
# Some college/university study without earning a...                                                180
# Something else                                                                                      8
#
# Employment                                          Independent contractor, freelancer, or self-employed;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 3
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                       70
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                    54
# Primary/elementary school                                                                           3
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                     12
# Secondary school (e.g. American high school, Ge...                                                 15
# ...
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      1
# Secondary school (e.g. American high school, Ge...                                                  2
# Some college/university study without earning a...                                                  2
# Something else                                                                                      0
#
# Employment                                          Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     1
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Not employed, but looking for work;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     1
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Student, full-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                     13
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           157
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                         25
# Primary/elementary school                                                                3
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                           1
# Secondary school (e.g. American high school, Ge...                                     110
# Some college/university study without earning a...                                      94
# Something else                                                                           4
#
# Employment                                          Student, full-time;Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 3
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                       14
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     9
# Primary/elementary school                                                                           1
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                 14
# Some college/university study without earning a...                                                 12
# Something else                                                                                      0
#
# Employment                                          Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 2
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                       20
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     3
# Primary/elementary school                                                                           2
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                 15
# Some college/university study without earning a...                                                 10
# Something else                                                                                      0
#
# Employment                                          Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     1
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  1
# Some college/university study without earning a...                                                  1
# Something else                                                                                      0
#
# Employment                                          Student, full-time;Not employed, but looking for work;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  4
# Some college/university study without earning a...                                                  1
# Something else                                                                                      1
#
# Employment                                          Student, full-time;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                                 0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                        0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                     0
# Primary/elementary school                                                                           1
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                      0
# Secondary school (e.g. American high school, Ge...                                                  0
# Some college/university study without earning a...                                                  0
# Something else                                                                                      0
#
# Employment                                          Student, part-time;Employed, part-time
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                     11
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           101
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                         40
# Primary/elementary school                                                                0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                           2
# Secondary school (e.g. American high school, Ge...                                      50
# Some college/university study without earning a...                                      45
# Something else                                                                           4

# %%
cross_tab.plot(kind='bar', stacked=True)

plt.title('Education vs Employment Type')
plt.xlabel('Education Level')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# #### Step 10: Save the Cleaned and Analyzed Dataset

# %% [markdown]
# After your analysis, save the modified dataset for further use or sharing.

# %%
cross_tab.plot(kind='bar', stacked=True)

plt.title('Education vs Employment Type')
plt.xlabel('Education Level')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# <h2>Summary</h2>

# %% [markdown]
# In this revised lab, you:
#
# - Loaded and explored the structure of the dataset.
#
# - Handled missing data effectively.
#
# - Analyzed key variables, including working hours, job satisfaction, and remote work trends.
#
# - Investigated programming language usage by region and examined the relationship between experience and satisfaction.
#
# - Used cross-tabulation to understand educational background and employment type.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
